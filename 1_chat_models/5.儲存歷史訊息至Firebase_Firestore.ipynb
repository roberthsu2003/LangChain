# %%
# Example Source: https://python.langchain.com/v0.2/docs/integrations/memory/google_firestore/

from dotenv import load_dotenv
from google.cloud import firestore
from langchain_google_firestore import FirestoreChatMessageHistory
from langchain_google_genai import ChatGoogleGenerativeAI

# 需要安裝的套件
"""
pip install google-cloud-firestore
pip install langchain-google-firestore
"""

"""

中文版步驟：
1. 建立一個 Firebase 帳號
2. 建立一個新的 Firebase 專案
    - 複製專案 ID
3. 在 Firebase 專案中建立 Firestore 資料庫
4. 在電腦上安裝 Google Cloud CLI
    - https://cloud.google.com/sdk/docs/install
    - mac可以使用homebrew安裝
        - brew install google-cloud-cli
    - windows可以使用chocolatey安裝
        - choco install google-cloud-sdk
        
    - 使用 Google Cloud CLI 認證您的 Google 帳號
        - https://cloud.google.com/docs/authentication/provide-credentials-adc#local-dev
        - 使用指令`gcloud auth application-default login`認證

    - 設定您的預設專案為新建立的 Firebase 專案
        - 使用指令`gcloud config set project <project_id>`設定預設專案
    
5. 在 Google Cloud Console 中啟用 Firestore API：
    - https://console.cloud.google.com/apis/enableflow?apiid=firestore.googleapis.com&project=crewai-automation

"""

load_dotenv()

# 設定 Firebase Firestore
PROJECT_ID = "firestore-project1-ee3e9" #建立Firestore的project id
SESSION_ID = "user_session_new"  # 這是Firestore 集合下的document的名稱
COLLECTION_NAME = "chat_history" #這是Firestore的collection name

# 初始化 Firestore 客戶端
print("正在初始化 Firestore 客戶端...")
client = firestore.Client(project=PROJECT_ID)

# 初始化 Firestore 聊天訊息歷史紀錄
print("正在初始化 Firestore 聊天訊息歷史紀錄...")
chat_history = FirestoreChatMessageHistory(
    session_id=SESSION_ID,
    collection=COLLECTION_NAME,
    client=client,
)
print("聊天歷史紀錄已初始化。")
print("目前的聊天歷史紀錄：", chat_history.messages)

# 初始化聊天模型
model = ChatGoogleGenerativeAI(model="gemini-2.5-flash")

print("開始與 AI 聊天。輸入 'exit' 可離開。")

while True:
    human_input = input("使用者: ")
    if human_input.lower() == "exit":
        break

    chat_history.add_user_message(human_input)

    ai_response = model.invoke(chat_history.messages)
    chat_history.add_ai_message(ai_response.content)

    print(f"AI: {ai_response.content}")

# 執行完後,可以到Firestore的console中查看,是否已經儲存了對話記錄
# Out:
# 正在初始化 Firestore 客戶端...
# 正在初始化 Firestore 聊天訊息歷史紀錄...
# 聊天歷史紀錄已初始化。
# 目前的聊天歷史紀錄： [HumanMessage(content='我叫robert', additional_kwargs={}, response_metadata={}), AIMessage(content='你好，Robert！很高兴认识你。有什么我可以帮助你的吗？', additional_kwargs={}, response_metadata={}), HumanMessage(content='請告訴我如何使用python', additional_kwargs={}, response_metadata={}), AIMessage(content='你好，Robert！很高興你對 Python 感興趣。Python 是一種非常流行且功能強大的程式語言，因其簡潔的語法和廣泛的應用而受到許多開發者的喜愛。\n\n這份指南將帶你從零開始了解 Python，包括如何安裝、基本語法和常見應用。\n\n---\n\n### Python 入門指南：如何使用 Python\n\n#### 1. 什麼是 Python？\n\nPython 是一種高階、直譯式、通用型的程式語言。它由 Guido van Rossum 於 1991 年創建，以其優雅的語法和易讀性而聞名。\n\n**主要特點：**\n*   **易學易用：** 語法簡潔，接近自然語言。\n*   **跨平台：** 可以在 Windows、macOS、Linux 等多種作業系統上運行。\n*   **開源：** 免費使用，擁有龐大的社群支援。\n*   **功能強大：** 擁有豐富的標準庫和第三方庫，可以完成幾乎任何任務。\n\n#### 2. 為什麼要學習 Python？\n\n*   **多功能性：** 適用於網頁開發、數據科學、機器學習、自動化、遊戲開發、桌面應用等。\n*   **高需求：** 在科技行業中，Python 開發者需求量很大。\n*   **入門友好：** 非常適合程式設計初學者。\n*   **豐富的生態系統：** 擁有大量的框架和庫（例如：Django, Flask, NumPy, Pandas, TensorFlow）。\n\n#### 3. 如何開始：安裝 Python\n\n首先，你需要將 Python 安裝到你的電腦上。\n\n1.  **訪問官方網站：** 前往 [python.org](https://www.python.org/)。\n2.  **下載：** 點擊 "Downloads" 選項，選擇適合你作業系統的最新穩定版本（通常是 Python 3.x）。\n3.  **安裝：**\n    *   **Windows:** 運行下載的 `.exe` 安裝程式。**非常重要的一步：在安裝過程中，請務必勾選 "Add Python X.X to PATH" 選項！** 這會讓你在命令提示字元中直接運行 Python。\n    *   **macOS:** 大部分 macOS 系統預裝了 Python 2.x，但建議安裝 Python 3.x。下載 `.pkg` 檔案並按照指示安裝。\n    *   **Linux:** 大部分 Linux 發行版都預裝了 Python。你可以使用套件管理器安裝最新版本（例如 `sudo apt-get install python3`）。\n4.  **驗證安裝：** 打開你的命令提示字元 (Windows: `cmd`, macOS/Linux: `Terminal`)，輸入以下命令並按 Enter：\n    ```bash\n    python --version\n    # 或者，如果 \'python\' 指向 Python 2.x，則嘗試：\n    python3 --version\n    ```\n    如果顯示類似 `Python 3.9.7` 的版本號，則表示安裝成功。\n\n#### 4. 你的第一個 Python 程式\n\n現在你已經安裝了 Python，讓我們來寫第一個程式！\n\n**方法一：使用互動式解釋器 (Interactive Shell)**\n\n1.  打開命令提示字元/終端機。\n2.  輸入 `python` (或 `python3`) 並按 Enter。你將看到 Python 提示符 `>>>`。\n3.  輸入以下程式碼：\n    ```python\n    print("Hello, Robert! Welcome to Python!")\n    ```\n4.  按 Enter，你將立即看到輸出：\n    ```\n    Hello, Robert! Welcome to Python!\n    ```\n5.  要退出互動式解釋器，輸入 `exit()` 並按 Enter。\n\n**方法二：創建一個 Python 腳本檔案**\n\n1.  打開任何文字編輯器（例如：VS Code, Sublime Text, Notepad++，甚至 Windows 內建的記事本）。\n2.  輸入以下程式碼：\n    ```python\n    # 這是一個單行註釋，用於解釋程式碼\n    print("Hello, Robert! This is your first Python script.")\n    print("Python is fun!")\n    ```\n3.  將檔案保存為 `first_script.py` (副檔名必須是 `.py`)。將它保存到一個你容易找到的資料夾，例如 `C:\\Users\\YourName\\PythonProjects`。\n4.  打開命令提示字元/終端機。\n5.  導航到你保存檔案的資料夾。例如：\n    ```bash\n    cd C:\\Users\\YourName\\PythonProjects\n    ```\n6.  運行你的腳本：\n    ```bash\n    python first_script.py\n    # 或者\n    python3 first_script.py\n    ```\n7.  你將看到程式的輸出：\n    ```\n    Hello, Robert! This is your first Python script.\n    Python is fun!\n    ```\n\n恭喜你！你已經成功運行了你的第一個 Python 程式。\n\n#### 5. Python 核心概念\n\n接下來，我們來學習一些 Python 的基本語法和概念。\n\n##### a. 註釋 (Comments)\n\n註釋是程式碼中被 Python 解釋器忽略的部分，用於解釋程式碼，提高可讀性。\n\n```python\n# 這是一個單行註釋\n\n"""\n這是一個多行註釋\n通常也稱為文檔字符串 (docstring)\n"""\n```\n\n##### b. 變數 (Variables)\n\n變數用於儲存數據。Python 是一種動態型別語言，你不需要在使用前聲明變數的型別。\n\n```python\nname = "Robert"      # 字符串 (string)\nage = 30             # 整數 (integer)\nheight = 1.75        # 浮點數 (float)\nis_student = True    # 布林值 (boolean)\n\nprint(name)\nprint(age)\nprint(height)\nprint(is_student)\n```\n\n##### c. 數據型別 (Data Types)\n\nPython 內建了多種數據型別：\n\n*   **數字 (Numbers):** `int` (整數), `float` (浮點數), `complex` (複數)。\n    ```python\n    num_int = 10\n    num_float = 3.14\n    ```\n*   **字符串 (Strings):** 用單引號或雙引號括起來的文本。\n    ```python\n    message = "Hello, Python!"\n    char = \'A\'\n    ```\n*   **布林值 (Booleans):** `True` 或 `False`。\n    ```python\n    is_active = True\n    ```\n*   **列表 (Lists):** 有序、可變的元素集合，用方括號 `[]` 表示。\n    ```python\n    fruits = ["apple", "banana", "cherry"]\n    print(fruits[0]) # 訪問第一個元素\n    fruits.append("orange") # 添加元素\n    ```\n*   **元組 (Tuples):** 有序、不可變的元素集合，用圓括號 `()` 表示。\n    ```python\n    coordinates = (10, 20)\n    # coordinates.append(30) # 這會報錯，因為元組不可變\n    ```\n*   **字典 (Dictionaries):** 無序、可變的鍵值對 (k ...
# 開始與 AI 聊天。輸入 'exit' 可離開。
# AI: 好的，Robert！我記住了。
#
# 很高興能幫助你學習 Python。如果你在學習過程中遇到任何問題，或者有任何想了解的特定主題，隨時都可以問我。
#
# 祝你學習愉快！
# AI: 您好，Robert！
#
# 很高興再次與您交流。有什麼我可以為您服務的嗎？無論是關於 Python 的問題、其他技術方面的疑問，還是您只是想聊聊，我都樂意提供幫助。
